# %%
digits = "..."

# %%
greatest = 0
for i in range(len(digits) - 13):
    test = digits[i:i+13]
    prod = 1
    for digit in test:
        if digit == "0":
            prod = 0
            break
        num = int(digit)
        prod *= num
    greatest = max(prod, greatest)
greatest
# Out:
# 23514624000
